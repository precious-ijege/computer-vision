# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
test_image = cv2.imread("test_image.jpeg")

print(test_image)
# Out:
# [[[153  31 255]
#   [153  31 255]
#   [156  33 255]
#   ...
#   [254  24 101]
#   [255  24 100]
#   [255  23  99]]
#
#  [[153  31 255]
#   [153  31 255]
#   [156  33 255]
#   ...
#   [254  24 101]
#   [255  24 100]
#   [255  23  99]]
#
#  [[153  31 255]
#   [153  31 255]
#   [155  32 254]
#   ...
#   [254  24 101]
#   [255  23  99]
#   [255  23  99]]
#
#  ...
#
#  [[ 67   3 233]
#   [ 67   3 233]
#   [ 68   4 234]
#   ...
#   [143   2 227]
#   [143   2 227]
#   [142   1 226]]
#
#  [[ 65   2 235]
#   [ 65   2 235]
#   [ 65   2 235]
#   ...
#   [143   2 227]
#   [142   1 226]
#   [142   1 226]]
#
#  [[ 62   2 234]
#   [ 62   2 234]
#   [ 63   3 235]
#   ...
#   [143   2 227]
#   [142   1 226]
#   [142   1 226]]]

# %%
plt.imshow(test_image)
